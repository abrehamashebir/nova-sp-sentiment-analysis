# %%
import os,sys
import pandas as pd

# %%
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.merge_all_stocks import process_and_merge_stocks

tickers = ['AAPL', 'AMZN', 'GOOG', 'MSFT', 'TSLA', 'NVDA', 'META']

# %%
merged_df = process_and_merge_stocks(tickers)
# Out:
# 📥 Processing AAPL...
#
# 📥 Processing AMZN...
#
# 📥 Processing GOOG...
#
# 📥 Processing MSFT...
#
# 📥 Processing TSLA...
#
# 📥 Processing NVDA...
#
# 📥 Processing META...
# /home/age/KAIM-Projects/nova-sp-sentiment-analysis/src/stock_data.py:40: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   self.df.fillna(method='ffill', inplace=True)
# /home/age/KAIM-Projects/nova-sp-sentiment-analysis/src/stock_data.py:40: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   self.df.fillna(method='ffill', inplace=True)
# /home/age/KAIM-Projects/nova-sp-sentiment-analysis/src/stock_data.py:40: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   self.df.fillna(method='ffill', inplace=True)
# ...

# %%
merged_df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 45423  2024-07-24  472.309998  476.299988  460.579987  461.269989  461.269989
# 45424  2024-07-25  463.260010  463.549988  442.649994  453.410004  453.410004
# 45425  2024-07-26  464.200012  469.769989  459.420013  465.700012  465.700012
# 45426  2024-07-29  469.880005  473.959991  465.019989  465.709991  465.709991
# 45427  2024-07-30  467.000000  472.730011  456.700012  463.190002  463.190002
#
# ...

# %%
from src.indicators import add_technical_indicators

# %%
df =add_technical_indicators(merged_df)

# %%
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 42501  2024-07-30  111.519997  111.989998  102.540001  103.730003  103.730003
# 22863  2024-07-30  171.830002  172.949997  170.119995  171.860001  171.860001
# 32535  2024-07-30  427.720001  429.049988  417.359985  422.920013  422.159119
# 36080  2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
# 45427  2024-07-30  467.000000  472.730011  456.700012  463.190002  463.190002
#
# ...

# %%
from src.indicators import plot_macd

# %%
for ticker in tickers:
    plot_macd(df, ticker)
# Out:
# /home/age/KAIM-Projects/nova-sp-sentiment-analysis/src/indicators.py:44: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/age/KAIM-Projects/nova-sp-sentiment-analysis/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

def plot_price_lines(df, ticker):
    plt.figure(figsize=(20, 8))
    
    plt.plot(df['Date'], df['Close'], label='Close')


    plt.title(f"{ticker} - Stock Price Overview")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
for ticker in tickers:
    plot_price_lines(df, ticker)

# %%
df.to_csv('../cleaned_datasets/merged_stocks_with_indicators.csv', index=False)
